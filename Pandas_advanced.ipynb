# %% [markdown]
# <a href="https://colab.research.google.com/github/Pushpit07/Data_Collection_using_Pandas/blob/main/Pandas_advanced.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = sns.load_dataset("iris")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df["sepal_length"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
names = ["Foo", "Bar", "Baz"]

# %%
ages = [25, 35, 32]

# %%
d = {
    "name": names,
     "age": ages
}

# %%
d
# Out:
# {'age': [25, 35, 32], 'name': ['Foo', 'Bar', 'Baz']}

# %%
pd.DataFrame(d)
# Out:
#   name  age
# 0  Foo   25
# 1  Bar   35
# 2  Baz   32

# %%
import numpy as np

# %%
data = np.random.randint(10, 20, (10, 5))

# %%
data
# Out:
# array([[10, 16, 15, 19, 16],
#        [12, 15, 15, 17, 18],
#        [12, 10, 12, 12, 16],
#        [11, 15, 17, 18, 19],
#        [19, 10, 12, 12, 12],
#        [10, 11, 10, 15, 16],
#        [13, 17, 17, 11, 10],
#        [11, 11, 10, 12, 18],
#        [12, 18, 11, 17, 15],
#        [13, 17, 11, 13, 18]])

# %%
pd.DataFrame(data)
# Out:
#     0   1   2   3   4
# 0  10  16  15  19  16
# 1  12  15  15  17  18
# 2  12  10  12  12  16
# 3  11  15  17  18  19
# 4  19  10  12  12  12
# 5  10  11  10  15  16
# 6  13  17  17  11  10
# 7  11  11  10  12  18
# 8  12  18  11  17  15
# 9  13  17  11  13  18

# %%
marks = pd.DataFrame(data, columns=['p', 'c', 'm', 'b', 'ss'])

# %%
marks
# Out:
#     p   c   m   b  ss
# 0  10  16  15  19  16
# 1  12  15  15  17  18
# 2  12  10  12  12  16
# 3  11  15  17  18  19
# 4  19  10  12  12  12
# 5  10  11  10  15  16
# 6  13  17  17  11  10
# 7  11  11  10  12  18
# 8  12  18  11  17  15
# 9  13  17  11  13  18

# %%
marks['bio'] = 0

# %%
marks
# Out:
#     p   c   m   b  ss  bio
# 0  10  16  15  19  16    0
# 1  12  15  15  17  18    0
# 2  12  10  12  12  16    0
# 3  11  15  17  18  19    0
# 4  19  10  12  12  12    0
# 5  10  11  10  15  16    0
# 6  13  17  17  11  10    0
# 7  11  11  10  12  18    0
# 8  12  18  11  17  15    0
# 9  13  17  11  13  18    0

# %%
df.values
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'setosa'],
#        [5.1, 3.7, 1.5, 0.4, 'setosa'],
#        [4.6, 3.6, 1.0, 0.2, 'setosa'],
#        [5.1, 3.3, 1.7, 0.5, 'setosa'],
# ...

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.T
# Out:
#                  0       1       2    ...        147        148        149
# sepal_length     5.1     4.9     4.7  ...        6.5        6.2        5.9
# sepal_width      3.5       3     3.2  ...          3        3.4          3
# petal_length     1.4     1.4     1.3  ...        5.2        5.4        5.1
# petal_width      0.2     0.2     0.2  ...          2        2.3        1.8
# species       setosa  setosa  setosa  ...  virginica  virginica  virginica
#
# [5 rows x 150 columns]

# %%
marks.sort_index(axis=1)
# Out:
#     b  bio   c   m   p  ss
# 0  19    0  16  15  10  16
# 1  17    0  15  15  12  18
# 2  12    0  10  12  12  16
# 3  18    0  15  17  11  19
# 4  12    0  10  12  19  12
# 5  15    0  11  10  10  16
# 6  11    0  17  17  13  10
# 7  12    0  11  10  11  18
# 8  17    0  18  11  12  15
# 9  13    0  17  11  13  18

# %%
 marks.sort_values(['m'])
# Out:
#     p   c   m   b  ss  bio
# 5  10  11  10  15  16    0
# 7  11  11  10  12  18    0
# 8  12  18  11  17  15    0
# 9  13  17  11  13  18    0
# 2  12  10  12  12  16    0
# 4  19  10  12  12  12    0
# 0  10  16  15  19  16    0
# 1  12  15  15  17  18    0
# 3  11  15  17  18  19    0
# 6  13  17  17  11  10    0

# %%
marks.iloc[:5, 1:3]
# Out:
#     c   m
# 0  16  15
# 1  15  15
# 2  10  12
# 3  15  17
# 4  10  12

# %%
marks.iloc[0:10:2]
# Out:
#     p   c   m   b  ss  bio
# 0  10  16  15  19  16    0
# 2  12  10  12  12  16    0
# 4  19  10  12  12  12    0
# 6  13  17  17  11  10    0
# 8  12  18  11  17  15    0

# %%
marks.iloc[[0,2,6]]
# Out:
#     p   c   m   b  ss  bio
# 0  10  16  15  19  16    0
# 2  12  10  12  12  16    0
# 6  13  17  17  11  10    0
